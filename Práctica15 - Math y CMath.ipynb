# %% [markdown]
# Este colab fue desarrollado por Arnold Charry Armero.

# %% [markdown]
# # Math y CMath en Python

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Muestra la veracidad de las siguientes propiedades de los logaritmos con 3 ejemplos diferentes en cada caso.
# En otras palabras, escoge 3 tríos de valores para a, b y c y comprueba que todas las propiedades se satisfacen:
#
#
#
# *   $\log_a 1 = 0 \: \forall a \in \mathbb{R} $
# *   $\log_a a = 1 \: \forall a \in \mathbb{R} $
# *   $\log_a b^{n} = n  \: \log_a b \: \forall a,b \in \mathbb{R}, n \in \mathbb{Z} $
# *   $\log_a b^{\frac{1}{n}} = \frac{1}{n}  \: \log_a b \: \forall a,b \in \mathbb{R}, n \in \mathbb{Z} $
# *   $ \log_a bc  = \log_a b + \log_a c \: \forall a,b, c \in \mathbb{R} $
# *   $ \log_a \frac{b}{c}  = \log_a b - \log_a c \: \forall a,b, c \in \mathbb{R} $
# *   $ \log_a b = \frac{\log_c b}{\log_c a} \: \forall a,b, c \in \mathbb{R}$

# %%
import math as mt
a = [2, 3, 4]
b = [3, 4, 5]
c = [4, 5, 6]
n = 2
for i in range(len(a)):
  if mt.log(1, a[i]) == 0:
    print("True1")
  if mt.log(a[i], a[i]) == 1:
    print("True2")
  if mt.log(b[i]**n, a[i]) == n * mt.log(b[i], a[i]):
    print("True3")
  if round(mt.log(b[i]**(1/n), a[i]), 4) == round((1/n) * mt.log(b[i], a[i]), 4):
    print("True4")
  if round(mt.log(b[i]*c[i], a[i]), 4) == round(mt.log(b[i], a[i]) + mt.log(c[i], a[i]), 4):
    print("True5")
  if round(mt.log(b[i]/c[i], a[i]), 4) == round(mt.log(b[i], a[i]) - mt.log(c[i], a[i]), 4):
    print("True6")
  if round(mt.log(b[i], c[i]) / mt.log(a[i], c[i]), 4) == round(mt.log(b[i], a[i]), 4):
    print("True7")
# Out:
# True1
# True2
# True3
# True4
# True5
# True6
# True7
# True1
# True2
# True3
# True4
# True5
# True6
# True7
# True1
# True2
# True3
# True4
# True5
# True6
# True7

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Crea una función que dado un número real representando grados lo transforme a radianes. Crea otra función
# que dado un valor real representando radianes lo transforme a grados.
# Comprueba que tus funciones calculan correctamente el resultado comparándolo con el obtenido con los
# métodos .degree() y .radians()
#
#
# EXTRA: Si en la primera función nos introducen un número fuera del intervalo [0, 360], devolver el equivalente en radianes dentro del intervalo [0, 2π]. Y, para la segunda función, si nos introducen un valor fuera
# del intervalo [0, 2π], devolver el equivalente en grados dentro del intervalo [0, 360]

# %%
def grados_a_radianes(grados):
  radianes = grados * (mt.pi / 180)
  return radianes

def radianes_a_grados(radianes):
  grados = radianes * (180 / mt.pi)
  return grados

print(grados_a_radianes(180))
print(radianes_a_grados(mt.pi))

print(mt.radians(180))
print(mt.degrees(mt.pi))
# Out:
# 3.141592653589793
# 180.0
# 3.141592653589793
# 180.0

# %%
#Extra
def degree_to_radian(d):
  rad = d + 2 * mt.pi / 360
  return rad - (rad // (1 * mt.pi)) * 2 * mt.pi

def radian_to_degree(r):
  deg = r * 360 / (2 * mt.pi)
  return deg - (deg // 360) * 360

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Elige cualquier valor para α y comprueba que,
#
# $$ \sin ^{2}(\alpha ) + \cos^{2}(\alpha ) = 1 $$
#
# $$ \tan (\alpha ) = \frac{\sin (a)}{\cos (a)} $$

# %%
a = 0.5
print(mt.sin(a)**2 + mt.cos(a)**2)
if mt.tan(a) == mt.sin(a) / mt.cos(a):
  print("True")
# Out:
# 1.0
# True

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Comprueba que, en Python, un número cualquiera dividido entre un número muy cercano a 0 sigue siendo
# considerado finito.

# %%
a = 10
b = 0.000000000000005
print(a/b)
# Out:
# 2000000000000000.0

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Elige valores enteros para n y k y comprueba si la siguiente igualdad es cierta:
#
# $$
# \binom{n}{k} = \binom{n}{n-k}
# $$

# %%
def choose(n, k):
  if (n >= k and k >= 0):
    return mt.factorial(n) / (mt.factorial(k) * mt.factorial(n-k))
  else:
    return "No se puede calcular el número factorial indicado"

n = 5
k = 2
print(choose(n, k) == choose(n, n-k))
# Out:
# True

# %% [markdown]
# ## Ejercicio 6

# %% [markdown]
# Transforma el complejo (1, -1) a coordenadas polares.

# %%
import cmath
cmath.polar(complex(1, -1))
# Out:
# (1.4142135623730951, -0.7853981633974483)

# %% [markdown]
# ## Ejercicio 7

# %% [markdown]
# Elige cualquier valor complejo para z y comprueba que,
#
# $$ \sinh = \frac{e^{z}- e^{-z}}{2} $$
#
# $$ \cosh = \frac{e^{z}+ e^{-z}}{2} $$

# %%
z = complex(0, 1)
cmath.isclose(cmath.sinh(z), (cmath.exp(z) - cmath.exp(-z)) / 2)
cmath.isclose(cmath.cosh(z), (cmath.exp(z) + cmath.exp(-z)) / 2)
# Out:
# True

# %% [markdown]
# ## Ejercicio 8

# %% [markdown]
# Elige cualquier valor complejo para z y comprueba que
#
# $$ \sinh(-z)=-\sinh(z) $$
#
# $$ \cosh(-z)=\cosh(z) $$

# %%
z = complex(1, 1)
cmath.sinh(-z) == -cmath.sinh(z)
cmath.cosh(-z) == cmath.cosh(z)
# Out:
# True

# %% [markdown]
# ## Ejercicio 9

# %% [markdown]
# Comprueba que tan (x) = 0 siendo x múltiplo de π. Prueba por ejemplo con los 10 primeros múltiplos
# negativos y positivos de π.

# %%
for i in range(-10, 11):
  print(mt.isclose(mt.tan(i * mt.pi), 0, abs_tol = 0.01))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## Ejercicio 10

# %% [markdown]
# Muestra con 3 ejemplos diferentes que la siguiente igualdad es cierta. Es decir, escoge valores diferentes para
# a, n y m, sustitúyelos y muestra que en ambos lados de la igualdad se obtiene el mismo resultado.
#
# $$ a^{m} \cdot a^{n} = a^{m+n} $$

# %%
a = [2, 3, 4]
m = [3, 4, 5]
n = [4, 5, 6]
for i in range(len(a)):
  if a[i]**m[i] * a[i]**n[i] == a[i]**(m[i] + n[i]):
    print("True")
# Out:
# True
# True
# True
