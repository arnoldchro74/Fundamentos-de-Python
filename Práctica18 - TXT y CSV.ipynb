# %% [markdown]
# Este colab fue desarrollado por Arnold Charry Armero.

# %% [markdown]
# # TXT and CSV en Python

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Pídele al usuario el nombre, el apellido, la edad y su color favorito. Guarda la información en un diccionario
# de claves name, surname, age y color.
# Crea y escribe un txt con 4 frases, una en cada línea. La primera debe indicar el nombre del usuario; la
# segunda, el apellido; la tercera, la edad; y la última, el color favorito del usuario.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
name = input("Introduce tu nombre: ")
surname = input("Introduce tu apellido: ")
age = input("Introduce tu edad: ")
color = input("Introduce tu color favorito: ")

user = {"name": name, "surname": surname, "age": age, "color": color}

f = open("/content/drive/MyDrive/Colab Notebooks/Python Basic Course/CSV and TXT/text_exercise.txt", mode = "x")
f.close()

f = open("/content/drive/MyDrive/Colab Notebooks/Python Basic Course/CSV and TXT/text_exercise.txt", mode = "a")
for i in user.values():
  f.write(i)
  f.write("\n")
f.close()
# Out:
# Introduce tu nombre: Arnold
# Introduce tu apellido: Charry
# Introduce tu edad: 21
# Introduce tu color favorito: Cyan

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Lee el archivo txt creado en el ejercicio anterior para ver que se ha creado correctamente.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Crea un archivo txt vacío y llámalo ej3.txt

# %%
f = open("/content/drive/MyDrive/Colab Notebooks/Python Basic Course/CSV and TXT/ej3.txt", mode = "x")
f.close()

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Elimina el archivo creado en el ejercicio 3.

# %%
import os
os.remove("/content/drive/MyDrive/Colab Notebooks/Python Basic Course/CSV and TXT/ej3.txt")

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Crea un archivo txt vacío y llámalo ej5.txt. Sobreescribelo con las siguientes líneas:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
f = open("/content/drive/MyDrive/Colab Notebooks/Python Basic Course/CSV and TXT/ej5.txt", mode = "x")
f = open("/content/drive/MyDrive/Colab Notebooks/Python Basic Course/CSV and TXT/ej5.txt", mode = "a")
f.write("x,y, Color, Shape \n")
f.write("1,1, #6fb7ff, < \n")
f.write("-1, 1, #ffa66f, v < \n")
f.write("-1, -1, #ffee6f, > \n")
f.write("1, -1, #db6fff, > \n")
f.close()

# %% [markdown]
# ## Ejercicio 6

# %% [markdown]
# Lee el archivo txt del ejercicio 5 como si fuera un archivo csv. Guarda las filas del objeto reader en una
# lista llamada df. Al final tendrás una lista con 5 listas de tamaño 4.

# %%
import csv
with open("/content/drive/MyDrive/Colab Notebooks/Python Basic Course/CSV and TXT/ej5.txt", "r") as f:
    reader = csv.reader(f)
    list1 = []
    for row in reader:
        print(row)
        list1.append(row)
# Out:
# ['x', 'y', ' Color', ' Shape ']
# ['1', '1', ' #6fb7ff', ' < ']
# ['-1', ' 1', ' #ffa66f', ' v < ']
# ['-1', ' -1', ' #ffee6f', ' > ']
# ['1', ' -1', ' #db6fff', ' > ']

# %% [markdown]
# ## Ejercicio 7

# %% [markdown]
# Utiliza el método .read_csv() de pandas para leer el contenido del txt del ejercicio 5 y guardarlo en un
# dataframe llamado df.

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Python Basic Course/CSV and TXT/ej5.txt")
df
# Out:
#    x  y     Color  Shape
# 0  1  1   #6fb7ff      <
# 1 -1  1   #ffa66f    v <
# 2 -1 -1   #ffee6f      >
# 3  1 -1   #db6fff      >

# %% [markdown]
# ## Ejercicio 8

# %% [markdown]
# Utiliza el dataframe df para representar los puntos cuyas coordenadas x están guardadas en la columna x
# y cuyas coordenadas y están guardadas en la columna y. Para ello utiliza el método .scatterplot() de
# seaborn.
# Pon de título “Puntos”. No muestres etiqueta en el eje horizontal ni en el eje vertical. Haz que el tamaño de
# la figure sea de 5 x 5 y que el tamaño de los puntos sea de 500.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,5))
sns.scatterplot(x = "x", y = "y", data = df, s = 500)
plt.title("Puntos")
# Out:
# Text(0.5, 1.0, 'Puntos')

# %% [markdown]
# ## Ejercicio 9

# %% [markdown]
# Modifica el gráfico anterior para que el color venga dado por la variable Color de df y la forma de los puntos,
# por la variable Shape.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
sns.scatterplot(x = "x", y = "y", data = df, s = 500, color = ['#6fb7ff', '#ffa66f', '#ffee6f', '#db6fff'])
plt.title("Puntos")
# Out:
# Text(0.5, 1.0, 'Puntos')

# %% [markdown]
# ## Ejercicio 10

# %% [markdown]
# Guarda en un csv la información de la lista data del ejercicio 6. Llama al archivo csv ej10.csv.

# %%
with open("/content/drive/MyDrive/Colab Notebooks/Python Basic Course/CSV and TXT/archivo", "w") as f:
  writer = csv.writer(f)
  for row in list1:
    writer.writerow(row)

with open("/content/drive/MyDrive/Colab Notebooks/Python Basic Course/CSV and TXT/archivo2", "w") as f:
  writer = csv.writer(f)
  writer.writerows(list1)
