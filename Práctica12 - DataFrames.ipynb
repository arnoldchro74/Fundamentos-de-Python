# %% [markdown]
# Este colab fue desarrollado por Arnold Charry Armero.

# %% [markdown]
# # Dataframes in Python

# %%
import pandas as pd

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Crea un dataframe con 15 filas y 2 columnas. La primera columna se llamará x, la segunda y. Cada entrada
# será un número real a tu elección. Guarda el dataframe en una variable llamada points.

# %%
data = {"x" : [1, -4, 7, 12, 5, -3, 8, 2, 9, -6, 11, -13, 15, 10, 14],
        "y" : [14, 10, 15, -13, 11, 6, 9, -2, 8, -3, 5, -12, 7, 4, 1]}

points = pd.DataFrame(data = data)
points.head(15)
# Out:
#      x   y
# 0    1  14
# 1   -4  10
# 2    7  15
# 3   12 -13
# 4    5  11
# 5   -3   6
# 6    8   9
# 7    2  -2
# 8    9   8
# 9   -6  -3
# 10  11   5
# 11 -13 -12
# 12  15   7
# 13  10   4
# 14  14   1

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Del dataset points, muestra las filas cuyo valor en la columna x sea positivo.

# %%
points[points["x"] > 0]
# Out:
#      x   y
# 0    1  14
# 2    7  15
# 3   12 -13
# 4    5  11
# 6    8   9
# 7    2  -2
# 8    9   8
# 10  11   5
# 12  15   7
# 13  10   4
# 14  14   1

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Del dataset points, muestra las filas cuyo valor en la columna y sea negativo. Usa el método .query().

# %%
points.query('y < 0')
# Out:
#      x   y
# 3   12 -13
# 7    2  -2
# 9   -6  -3
# 11 -13 -12

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Del dataset points, muestra las observaciones cuyos puntos (x, y) pertenezcan al primer cuadrante. Usa el
# método .query().

# %%
points.query("x > 0 and y > 0")
# Out:
#      x   y
# 0    1  14
# 2    7  15
# 4    5  11
# 6    8   9
# 8    9   8
# 10  11   5
# 12  15   7
# 13  10   4
# 14  14   1

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Del dataset points, muestra las observaciones de la forma: “El punto ({x}, {y}) {no/sí} pertenece al primer
# cuadrante”.

# %%
for row in points.itertuples():
  print("El punto ({}, {}) {} pertence al primer cuadrante".
        format(row[1], row[2], "sí" if row[1] > 0 and row[2] > 0 else "no"))
# Out:
# El punto (1, 14) sí pertence al primer cuadrante
# El punto (-4, 10) no pertence al primer cuadrante
# El punto (7, 15) sí pertence al primer cuadrante
# El punto (12, -13) no pertence al primer cuadrante
# El punto (5, 11) sí pertence al primer cuadrante
# El punto (-3, 6) no pertence al primer cuadrante
# El punto (8, 9) sí pertence al primer cuadrante
# El punto (2, -2) no pertence al primer cuadrante
# El punto (9, 8) sí pertence al primer cuadrante
# El punto (-6, -3) no pertence al primer cuadrante
# El punto (11, 5) sí pertence al primer cuadrante
# El punto (-13, -12) no pertence al primer cuadrante
# El punto (15, 7) sí pertence al primer cuadrante
# El punto (10, 4) sí pertence al primer cuadrante
# El punto (14, 1) sí pertence al primer cuadrante

# %% [markdown]
# ## Ejercicio 6

# %% [markdown]
# Crea un dataframe con 10 filas y 4 columnas. La primera columna se llamará word; la segunda, length;
# la tercera, vowels; y la última, consonants. La columna words contendrá las siguientes 10 palabras:
# “euro”, “diez” “algas”, “broma”, “cicuta”, “fatiga”, “nachos”, “jadeos”, “hazañas”, “boutique”. Las columnas
# length, vowels y consonants contendrán, respectivamente, la longitud, el total de vocales y el total de
# consonantes. Guarda el dataframe en la variable words.

# %%
def vowels(word):

  vow_count = 0
  for i in word:
    if i == "a" or i == "e" or i == "i" or i == "o" or i == "u":
      vow_count += 1

  return vow_count

# %%
def consonants(word):

  con_count = 0
  for i in word:
    if i != "a" and i != "e" and i != "i" and i != "o" and i != "u":
      con_count += 1

  return con_count

# %%
words = ["euro", "diez", "algas", "broma", "cicuta", "fatiga", "nachos", "jadeos", "hazañas", "boutique"]

words_data = {"words" : words,
        "length" : map(len, words),
        "vowels" : map(vowels, words),
        "consonants" : map(consonants, words)}

words = pd.DataFrame(words_data)
words.head(10)
# Out:
#       words  length  vowels  consonants
# 0      euro       4       3           1
# 1      diez       4       2           2
# 2     algas       5       2           3
# 3     broma       5       2           3
# 4    cicuta       6       3           3
# 5    fatiga       6       3           3
# 6    nachos       6       2           4
# 7    jadeos       6       3           3
# 8   hazañas       7       3           4
# 9  boutique       8       5           3

# %% [markdown]
# ## Ejercicio 7

# %% [markdown]
# Muestra las 10 observaciones de words con el formato “La palabra {word} tiene {length} letras, de las cuales
# {vowels} son vocales y {consonants} consonantes”.

# %%
for row in words.itertuples():
    print("La palabra {} tiene {} letras, de las cuales {} son vocales y {} consonantes.".
        format(row[1], row[2], row[3], row[4]))
# Out:
# La palabra euro tiene 4 letras, de las cuales 3 son vocales y 1 consonantes.
# La palabra diez tiene 4 letras, de las cuales 2 son vocales y 2 consonantes.
# La palabra algas tiene 5 letras, de las cuales 2 son vocales y 3 consonantes.
# La palabra broma tiene 5 letras, de las cuales 2 son vocales y 3 consonantes.
# La palabra cicuta tiene 6 letras, de las cuales 3 son vocales y 3 consonantes.
# La palabra fatiga tiene 6 letras, de las cuales 3 son vocales y 3 consonantes.
# La palabra nachos tiene 6 letras, de las cuales 2 son vocales y 4 consonantes.
# La palabra jadeos tiene 6 letras, de las cuales 3 son vocales y 3 consonantes.
# La palabra hazañas tiene 7 letras, de las cuales 3 son vocales y 4 consonantes.
# La palabra boutique tiene 8 letras, de las cuales 5 son vocales y 3 consonantes.

# %% [markdown]
# ## Ejercicio 8

# %% [markdown]
# Muestra aquellas observaciones de words que tienen el mismo número de vocales y consonantes. Usa el
# método .query().

# %%
words.query("vowels == consonants")
# Out:
#     words  length  vowels  consonants
# 1    diez       4       2           2
# 4  cicuta       6       3           3
# 5  fatiga       6       3           3
# 7  jadeos       6       3           3

# %% [markdown]
# ## Ejercicio 9

# %% [markdown]
# Investiga el método .sort_values() para ordenar las observaciones según la longitud de las palabras en
# orden descendente.

# %%
words.sort_values(by = "length", ascending = False)
# Out:
#       words  length  vowels  consonants
# 9  boutique       8       5           3
# 8   hazañas       7       3           4
# 4    cicuta       6       3           3
# 5    fatiga       6       3           3
# 6    nachos       6       2           4
# 7    jadeos       6       3           3
# 2     algas       5       2           3
# 3     broma       5       2           3
# 0      euro       4       3           1
# 1      diez       4       2           2

# %% [markdown]
# ## Ejercicio 10

# %% [markdown]
# Convierte la columna vowels a lista y, con sorted() ordénala de mayor a menor. Investiga para ello el
# método .tolist().

# %%
vowels_list = words["vowels"].tolist()
sorted(vowels_list, reverse = True)
# Out:
# [5, 3, 3, 3, 3, 3, 2, 2, 2, 2]
