# %% [markdown]
# Este colab fue desarrollado por Arnold Charry Armero.

# %% [markdown]
# # Números en Python

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Calcula la división entera de 45 entre 6.

# %%
45 // 6
# Out:
# 7

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Calcula el resto de la división entera de 45 entre 6.

# %%
45 % 6
# Out:
# 3

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Realiza la siguiente operación en python, donde la división es entera:
# $$ 10 + \frac{20}{7} - 2 $$

# %%
10 + 20 // 7 - 2
# Out:
# 10

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Realiza la siguiente operación en Python:
# $$ \frac{9-\frac{25+5-2}{7*4}}{2^{3}}$$

# %%
(9 - (25 + 5 - 2) / (7 * 4)) / 2**3
# Out:
# 1.0

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Realiza la siguiente operación en Python:
# $$ \frac{2+2^{3}-2\cdot (2-2^{5})+2^{2}\cdot 2+2}{2 \cdot (2 \cdot 2-2^{4}) + 2^{2}}$$

# %%
(2 + 2**3 - 2 * (2 - 2**5) + 2**2 * 2 + 2) / (2 * (2 * 2 - 2**4) + 2**2)
# Out:
# -4.0

# %% [markdown]
# ## Ejercicio 6

# %% [markdown]
# Realiza la siguiente operación en Python:

# %% [markdown]
# $$ 6i - (4+i) \cdot 2$$

# %%
6j - (4+1j)*2
# Out:
# (-8+4j)

# %% [markdown]
# ## Ejercicio 7

# %% [markdown]
# Realiza la siguiente operación en Python:

# %% [markdown]
# $$ \frac{1+i}{1-i} + \frac{2}{-1+i} $$

# %%
(1+1j) / (1-1j) + 2 / (-1+1j)
# Out:
# (-1+0j)

# %% [markdown]
# ## Ejercicio 8

# %% [markdown]
# Realiza la siguiente operación en Python:

# %% [markdown]
# $$(1+i)^{2}$$

# %%
(1+1j)**2
# Out:
# 2j

# %% [markdown]
# ## Ejercicio 9

# %% [markdown]
# Realiza la siguiente operación en Python, donde $Mod(z)$ indica el módulo del complejo z:

# %% [markdown]
# $$ Mod \left (\frac{9-3i}{-2-i} \right )$$

# %%
abs((9-3j)/(-2-1j))
# Out:
# 4.242640687119285

# %% [markdown]
# ## Ejercicio 10

# %% [markdown]
# ¿Cuál es el argumento del número complejo $i$?

# %%
import cmath
cmath.phase(1j)
# Out:
# 1.5707963267948966
