# %% [markdown]
# Este colab fue desarrollado por Arnold Charry Armero.

# %% [markdown]
# # Strings en Python

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Utiliza las funciones de concatenar, + y repetir strings, *, junto con la función print() para dados los siguientes strings s1, s2, s3 y s4, consiguiendo el resultado siguiente: Había una vez, un barquito chiquitito. Había una vez, un barquito chiquitito que no podía, que no podía navegar.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s1 = "Había una vez, "
s2 = "un barquito chiquitito "
s3 = "que no podía, "
s4 = "que no podía navegar."

# %%
print(s1 + s2.strip() + ". " + s1 + s2 + s3 + s4)
# Out:
# Había una vez, un barquito chiquitito. Había una vez, un barquito chiquitito que no podía, que no podía navegar.

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Utiliza la función print() y el comando de salto de línea, \n, para reproducir exactamente el siguiente texto:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Érase un hombre a una nariz pegado, \nÉrase una nariz superlativa, \nÉrase una alquitara medio viva, \nÉrase un peje espada mal barbado;")
# Out:
# Érase un hombre a una nariz pegado,
# Érase una nariz superlativa,
# Érase una alquitara medio viva,
# Érase un peje espada mal barbado;

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Transforma el siguiente string s a mayúsculas y muéstralo por pantalla con la función print()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = "me encantan las matemáticas"
print(s.upper())
# Out:
# ME ENCANTAN LAS MATEMÁTICAS

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Calcula la longitud del string s

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = "Mi pasión por el chocolate es superior a mis fuerzas"
len(s)
# Out:
# 52

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Del string s del ejercicio anterior, obtén el substring chocolate y guárdalo en una variable llamada s_sub. No vale contar, deberás hallar los índices del substring con el método .find() (o el que mejor consideres) y la función len().
# Finalmente, imprime tu resultado por pantalla.

# %%
s_sub = s[s.find("chocolate"): (s.find("chocolate") + len("chocolate"))]
print(s_sub)
# Out:
# chocolate

# %% [markdown]
# ## Ejercicio 6

# %% [markdown]
# Con la función input(), indícale al usuario que introduzca su nombre y guárdalo en una variable llamada nombre.

# %%
nombre = input("Por favor escribe tu nombre: ")
# Out:
# Por favor escribe tu nombre: Arnold

# %% [markdown]
# ## Ejercicio 7

# %% [markdown]
# Con la función input(), indícale al usuario que introduzca su apellido y guárdalo en la variable llamada apellido.

# %%
apellido = input("Por favor escribe tu apellido: ")
# Out:
# Por favor escribe tu apellido: Charry

# %% [markdown]
# ## Ejercicio 8

# %% [markdown]
# Con la función input(), indícale al usuario que introduzca su edad y guárdala en la variable llamada edad. ¡Ojo con el tipo de dato!

# %%
edad = int(input("Por favor escribe tu edad: "))
# Out:
# Por favor escribe tu edad: 20

# %% [markdown]
# ## Ejercicio 9

# %% [markdown]
# Con la función input(), indícale al usuario que introduzca la ciudad en la que vive y guárdala en la variable llamada ciudad.

# %%
ciudad = input("Por favor escribe tu ciudad: ")
# Out:
# Por favor escribe tu ciudad: Cali

# %% [markdown]
# ## Ejercicio 10

# %% [markdown]
# Con lo hecho en los ejercicios 6, 7, 8 y 9, imprime por pantalla todos los datos introducidos por el usuario tal y como se muestra en el siguiente ejemplo, donde el usuario ha indicado que su nombre es María; su apellido, Santos; su edad, 21; y su ciudad, Palma de Mallorca.
#
# Su nombre es María Santos, tiene 21 años y actualmente vive en Palma de Mallorca.

# %%
print("Su nombre es {} {}, tiene {} años y actualmente vive en {}.". format(nombre, apellido, edad, ciudad))
# Out:
# Su nombre es Arnold Charry, tiene 20 años y actualmente vive en Cali.
