# %% [markdown]
# # Exportar de Colab a PDF

# %%
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc
# !apt-get install texlive-xetex texlive-fonts-recommended texlive-generic-recommended
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pandoc is already the newest version (2.9.2.1-3ubuntu2).
# texlive is already the newest version (2021.20220204-1).
# texlive-latex-extra is already the newest version (2021.20220204-1).
# texlive-xetex is already the newest version (2021.20220204-1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package texlive-generic-recommended

# %%
# Hora colombiana
# !sudo ln -sf /usr/share/zoneinfo/America/Bogota /etc/localtime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Módulo 1

# %% [markdown]
# ### Evidencia de Aprendizaje 1

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 1/Práctica de Condicionales.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 1/Práctica de Condicionales.ipynb to pdf
# [NbConvertApp] Writing 38940 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 45013 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 1/Práctica de Condicionales.pdf

# %% [markdown]
# ### Evidencia de Aprendizaje 2

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 2/Práctica de Acumuladores y Contadores.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 2/Práctica de Acumuladores y Contadores.ipynb to pdf
# [NbConvertApp] Writing 30920 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 36672 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 2/Práctica de Acumuladores y Contadores.pdf

# %% [markdown]
# ### Evidencia de Aprendizaje 3

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 3/Práctica de Repetición Indefinida.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 3/Práctica de Repetición Indefinida.ipynb to pdf
# [NbConvertApp] Writing 35001 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 37684 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 3/Práctica de Repetición Indefinida.pdf

# %% [markdown]
# ### Evidencia de Aprendizaje 4

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 4/Práctica de Ciclos: Banderas.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 4/Práctica de Ciclos: Banderas.ipynb to pdf
# [NbConvertApp] Writing 27898 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 31575 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 4/Práctica de Ciclos: Banderas.pdf

# %% [markdown]
# ### Evidencia de Aprendizaje 5

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 5/Práctica de Ciclos: Mayores y Menores.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 5/Práctica de Ciclos: Mayores y Menores.ipynb to pdf
# [NbConvertApp] Writing 36065 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 40306 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 5/Práctica de Ciclos: Mayores y Menores.pdf

# %% [markdown]
# ### Evidencia de Aprendizaje 6

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 6/Práctica de Ciclos: For.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 6/Práctica de Ciclos: For.ipynb to pdf
# [NbConvertApp] Writing 34844 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 42680 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 1 - Introducción a la Programación en Python/Evidencia de Aprendizaje/Actividad 6/Práctica de Ciclos: For.pdf

# %% [markdown]
# ## Módulo 2

# %% [markdown]
# ### Evidencia de Aprendizaje 1

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 1/Práctica de Funciones.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 1/Práctica de Funciones.ipynb to pdf
# [NbConvertApp] Writing 24498 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 25616 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 1/Práctica de Funciones.pdf

# %% [markdown]
# ### Evidencia de Aprendizaje 2

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 2/Práctica de Listas: Nivel 1.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 2/Práctica de Listas: Nivel 1.ipynb to pdf
# [NbConvertApp] Writing 26289 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 26895 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 2/Práctica de Listas: Nivel 1.pdf

# %% [markdown]
# ### Evidencia de Aprendizaje 3

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 3/Práctica de Listas: Nivel 2.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 3/Práctica de Listas: Nivel 2.ipynb to pdf
# [NbConvertApp] Writing 39721 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 43552 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 3/Práctica de Listas: Nivel 2.pdf

# %% [markdown]
# ### Evidencia de Aprendizaje 4

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 4/Práctica de Diccionarios.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 4/Práctica de Diccionarios.ipynb to pdf
# [NbConvertApp] Writing 38014 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 40957 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 2 - Estructuras de Datos y Funciones/Evidencia de Aprendizaje/Actividad 4/Práctica de Diccionarios.pdf

# %% [markdown]
# ## Módulo 3

# %% [markdown]
# ### Evidencia de Aprendizaje 1

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 3 - Programación Orientada a Objetos (POO)/Evidencia de Aprendizaje/Actividad 1/Práctica de Programación Orientada a Objetos.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 3 - Programación Orientada a Objetos (POO)/Evidencia de Aprendizaje/Actividad 1/Práctica de Programación Orientada a Objetos.ipynb to pdf
# [NbConvertApp] Writing 27193 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 32114 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 3 - Programación Orientada a Objetos (POO)/Evidencia de Aprendizaje/Actividad 1/Práctica de Programación Orientada a Objetos.pdf

# %% [markdown]
# ## Módulo 4

# %% [markdown]
# ## Evidencia de Aprendizaje 1

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 4 - Librerías y IA/Evidencia de Aprendizaje/Actividad 1/Práctica de Pandas - Análisis de Datos.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 4 - Librerías y IA/Evidencia de Aprendizaje/Actividad 1/Práctica de Pandas - Análisis de Datos.ipynb to pdf
# [NbConvertApp] Writing 38414 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 42807 bytes to /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 4 - Librerías y IA/Evidencia de Aprendizaje/Actividad 1/Práctica de Pandas - Análisis de Datos.pdf

# %% [markdown]
# ## Evidencia de Aprendizaje 2

# %%
# !jupyter nbconvert --to pdf "/content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 4 - Librerías y IA/Evidencia de Aprendizaje/Actividad 2/Práctica de Pandas - Generación de Código con ChatGPT.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Diplomados/Diplomado de Programación en Python/Módulo 4 - Librerías y IA/Evidencia de Aprendizaje/Actividad 2/Práctica de Pandas - Generación de Código con ChatGPT.ipynb to pdf
# [NbConvertApp] Support files will be in Práctica de Pandas - Generación de Código con ChatGPT_files/
# [NbConvertApp] Making directory ./Práctica de Pandas - Generación de Código con ChatGPT_files
# [NbConvertApp] Writing 48710 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# ...
